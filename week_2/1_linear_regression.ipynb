# %% [markdown]
# 🔹 Section 1: Linear Regression
# 🎯 Goal:
# Learn how to use linear regression to model relationships between variables — specifically how one feature (like total_bill) can predict another (like tip).
# ✅ What You’ll Learn:
# How to load real-world data using Pandas
# How to visualize relationships between variables with Matplotlib
# How to fit a Linear Regression model using scikit-learn
# How to make predictions using the trained model
# How to evaluate model performance with metrics like:
# Mean Squared Error (MSE)
# R² score (coefficient of determination)

# %% [markdown]
# Predicting Tips from Total Bill

# %%
# 📌 Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 📥 Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 📦 Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 🧠 Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# 🎯 Select features (X) and target (y)
X = df[['total_bill']]  # Feature must be 2D
y = df['tip']           # Target variable

# 🛠️ Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# 🔮 Make predictions
y_pred = model.predict(X)

# 📈 Plot actual vs predicted
plt.scatter(df['total_bill'], df['tip'], label="Actual Tips", color='blue')
plt.plot(df['total_bill'], y_pred, color='red', label="Predicted Tips")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.title("Linear Regression: Tip vs Total Bill")
plt.legend()
plt.grid(True)
plt.show()

# 📊 Evaluation
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("🔍 Model Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# 🔍 Model Evaluation:
# Mean Squared Error (MSE): 1.04
# R² Score: 0.46
